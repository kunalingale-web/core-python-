# %%
a = 110 - 1110

# %%
b = 5.555 + 89.78256

# %%
c = 25 *25 * 45 - 85

# %%
print (a + c + b)
print (type(a)), print (type(b)), print (type(c))
print (id(a),
      id(b),
      id(c))
# Out:
# 27135.33756
# <class 'int'>
# <class 'float'>
# <class 'int'>
# 2282852328656 2282851195088 2282852328240
