# %%
a ="kunal"

# %%
b = "age is 22"

# %%
c =  True

# %%
print((a),(b),(c))
print(type(a) , type(b),type(c))
print(id(a),id(b),id(c))
# Out:
# kunal age is 22 True
# <class 'str'> <class 'str'> <class 'bool'>
# 1820700031712 1820701904496 140733840370432
