# %%
a = 110 + 1110

# %%
b = 45.5+ 89.4

# %%
c = 69 + 55 - 87 +87

# %%
print (a + c + b)
print (type(a)), print (type(b)), print (type(c))
print (id(a),
      id(b),
      id(c))
# Out:
# 1478.9
# <class 'int'>
# <class 'float'>
# <class 'int'>
# 1340587125488 1340587117552 140733841273816
