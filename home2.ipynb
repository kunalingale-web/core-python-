# %%
x = "kunal"

# %%
y = "ganesh"

# %%
z = "ingale"

# %%
print((x),(y),(z))
print(type(x) , type(y),type(z))
print(id(x),id(y),id(z))
# Out:
# kunal ganesh ingale
# <class 'str'> <class 'str'> <class 'str'>
# 1893950235264 1893972673616 1893974358464
